# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("//Users/likhith/Downloads/OELP-CROP MODELLING/dataset.csv")

# %%
df.isnull()
# Out:
#        loc_ID   year  yield  W_1_1  W_1_2  W_1_3  W_1_4  W_1_5  W_1_6  W_1_7  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 25340   False  False  False  False  False  False  False  False  False  False
# 25341   False  False  False  False  False  False  False  False  False  False
# 25342   False  False  False  False  False  False  False  False  False  False
# 25343   False  False  False  False  False  False  False  False  False  False
# 25344   False  False  False  False  False  False  False  False  False  False
#
#        ...    P_5    P_6    P_7    P_8    P_9   P_10   P_11   P_12   P_13  \
# 0      ...  False  False  False  False  False  False  False  False  False
# 1      ...  False  False  False  False  False  False  False  False  False
# 2      ...  False  False  False  False  False  False  False  False  False
# 3      ...  False  False  False  False  False  False  False  False  False
# 4      ...  False  False  False  False  False  False  False  False  False
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 25340  ...  False  False  False  False  False  False  False  False  False
# 25341  ...  False  False  False  False  False  False  False  False  False
# 25342  ...  False  False  False  False  False  False  False  False  False
# 25343  ...  False  False  False  False  False  False  False  False  False
# 25344  ...  False  False  False  False  False  False  False  False  False
#
#         P_14
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 25340  False
# 25341  False
# 25342  False
# 25343  False
# 25344  False
#
# [25345 rows x 395 columns]

# %%
df.isnull().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of        loc_ID   year  yield  W_1_1  W_1_2  W_1_3  W_1_4  W_1_5  W_1_6  W_1_7  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 25340   False  False  False  False  False  False  False  False  False  False
# 25341   False  False  False  False  False  False  False  False  False  False
# 25342   False  False  False  False  False  False  False  False  False  False
# 25343   False  False  False  False  False  False  False  False  False  False
# 25344   False  False  False  False  False  False  False  False  False  False
#
#        ...    P_5    P_6    P_7    P_8    P_9   P_10   P_11   P_12   P_13  \
# 0      ...  False  False  False  False  False  False  False  False  False
# 1      ...  False  False  False  False  False  False  False  False  False
# 2      ...  False  False  False  False  False  False  False  False  False
# 3      ...  False  False  False  False  False  False  False  False  False
# 4      ...  False  False  False  False  False  False  False  False  False
# ...    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 25340  ...  False  False  False  False  False  False  False  False  False
# 25341  ...  False  False  False  False  False  False  False  False  False
# 25342  ...  False  False  False  False  False  False  False  False  False
# 25343  ...  False  False  False  False  False  False  False  False  False
# 25344  ...  False  False  False  False  False  False  False  False  False
#
#         P_14
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# ...      ...
# 25340  False
# 25341  False
# 25342  False
# 25343  False
# 25344  False
#
# [25345 rows x 395 columns]>

# %%
print(df['yield'].mean())
print(df['yield'].median())
print(df['yield'].mode())
print(df['yield'].var())
print(df['yield'].max())
print(df['yield'].min())
print(df['yield'].idxmax())
print(df['yield'].idxmin())
# Out:
# 38.51852436377984
# 38.5
# 0    38.0
# Name: yield, dtype: float64
# 121.73914113049263
# 82.3
# 2.9
# 2952
# 24977

# %%
for x in df.columns:
    column = df[x]
    count = (column == 0).sum()
    if count > 0 :
        print(x, end="   --   ")
        print(count, end="\n\n")
# Out:
# loc_ID   --   39
#
# W_1_1   --   7368
#
# W_1_2   --   7456
#
# W_1_3   --   6368
#
# W_1_4   --   6555
#
# W_1_5   --   5562
#
# W_1_6   --   5669
#
# W_1_7   --   6891
#
# W_1_8   --   5994
#
# W_1_9   --   6006
#
# W_1_10   --   5800
#
# W_1_11   --   5751
#
# W_1_12   --   3682
#
# W_1_13   --   2518
#
# W_1_14   --   3765
#
# W_1_15   --   3772
#
# W_1_16   --   2965
#
# W_1_17   --   2468
#
# W_1_18   --   2433
#
# W_1_19   --   1452
#
# W_1_20   --   2372
#
# W_1_21   --   1187
#
# W_1_22   --   1433
#
# W_1_23   --   2600
#
# W_1_24   --   1907
#
# W_1_25   --   2233
#
# W_1_26   --   3078
#
# W_1_27   --   3675
#
# W_1_28   --   3212
#
# W_1_29   --   3483
#
# W_1_30   --   2904
#
# W_1_31   --   3107
#
# W_1_32   --   2965
#
# W_1_33   --   3225
#
# W_1_34   --   3380
#
# W_1_35   --   4639
#
# W_1_36   --   4796
#
# W_1_37   --   4032
#
# W_1_38   --   3258
#
# W_1_39   --   5466
#
# W_1_40   --   7161
#
# W_1_41   --   5940
#
# W_1_42   --   5415
#
# W_1_43   --   6096
#
# W_1_44   --   6276
#
# W_1_45   --   7235
#
# W_1_46   --   7136
#
# W_1_47   --   7324
#
# W_1_48   --   5808
#
# W_1_49   --   6346
#
# W_1_50   --   5954
#
# W_1_51   --   5826
#
# W_1_52   --   5842
#
# W_3_1   --   5500
#
# W_3_2   --   4782
#
# W_3_3   --   4024
#
# W_3_4   --   4286
#
# W_3_5   --   4168
#
# W_3_6   --   4153
#
# W_3_7   --   4173
#
# W_3_8   --   5485
#
# W_3_9   --   6551
#
# W_3_10   --   7081
#
# W_3_11   --   9132
#
# W_3_12   --   11819
#
# W_3_13   --   14819
#
# W_3_14   --   17651
#
# W_3_15   --   19291
#
# W_3_16   --   21416
#
# W_3_17   --   23059
#
# W_3_18   --   24096
#
# W_3_19   --   24718
#
# W_3_20   --   25011
#
# W_3_21   --   25213
#
# W_3_22   --   25306
#
# W_3_23   --   25333
#
# W_3_24   --   25343
#
# W_3_25   --   25345
#
# W_3_26   --   25345
#
# W_3_27   --   25345
#
# W_3_28   --   25345
#
# W_3_29   --   25345
#
# W_3_30   --   25345
#
# W_3_31   --   25345
#
# W_3_32   --   25345
#
# W_3_33   --   25345
#
# W_3_34   --   25345
#
# W_3_35   --   25345
#
# W_3_36   --   25345
#
# W_3_37   --   25345
#
# W_3_38   --   25343
#
# W_3_39   --   25340
#
# W_3_40   --   25302
#
# W_3_41   --   25204
#
# W_3_42   --   25131
#
# W_3_43   --   24867
#
# W_3_44   --   23757
#
# W_3_45   --   22444
#
# W_3_46   --   20020
#
# W_3_47   --   18621
#
# W_3_48   --   16103
#
# W_3_49   --   12763
#
# W_3_50   --   10735
#
# W_3_51   --   9465
#
# W_3_52   --   7056
#
# W_4_1   --   9
#
# W_4_2   --   2
#
# W_4_3   --   3
#
# W_4_4   --   4
#
# W_4_5   --   8
#
# W_4_6   --   7
#
# W_4_7   --   7
#
# W_4_8   --   3
#
# W_4_9   --   6
#
# W_4_10   --   4
#
# W_4_11   --   1
#
# W_4_12   --   2
#
# W_4_44   --   1
#
# W_4_45   --   1
#
# W_4_46   --   1
#
# W_4_47   --   1
#
# W_4_48   --   2
#
# W_4_49   --   6
#
# W_4_50   --   4
#
# W_4_51   --   7
#
# W_4_52   --   9
#
# W_5_1   --   4
#
# W_5_2   --   1
#
# W_5_3   --   1
#
# W_5_5   --   4
#
# W_5_6   --   2
#
# W_5_7   --   3
#
# W_5_8   --   5
#
# W_5_9   --   1
#
# W_5_10   --   8
#
# W_5_11   --   7
#
# W_5_12   --   7
#
# W_5_13   --   9
#
# W_5_14   --   10
#
# W_5_15   --   12
#
# W_5_16   --   7
#
# W_5_17   --   3
#
# W_5_18   --   2
#
# W_5_40   --   1
#
# W_5_41   --   3
#
# W_5_42   --   4
#
# W_5_43   --   5
#
# W_5_44   --   13
#
# W_5_45   --   10
#
# W_5_46   --   11
#
# W_5_47   --   4
#
# W_5_48   --   6
#
# W_5_49   --   3
#
# W_5_50   --   4
#
# W_5_51   --   1
#
# W_5_52   --   4
#
# P_1   --   23891
#
# P_2   --   16620
#
# P_3   --   7350
#
# P_4   --   733
#
# P_5   --   264
#
# P_6   --   271
#
# P_7   --   200
#
# P_8   --   1124
#
# P_9   --   2980
#
# P_10   --   8860
#
# P_11   --   15219
#
# P_12   --   22046
#
# P_13   --   25181
#
# P_14   --   25260

# %%
df = df.drop('loc_ID', axis = 'columns')
df = df.drop('year', axis = 'columns')
df = df.drop('P_1', axis = 'columns')
df = df.drop('P_2', axis = 'columns')
df = df.drop('P_11', axis = 'columns')
df = df.drop('P_12', axis = 'columns')
df = df.drop('P_13', axis = 'columns')
df = df.drop('P_14', axis = 'columns')

# %%
df = df.drop('W_1_1',axis = 'columns')
df = df.drop('W_1_2',axis = 'columns')
df = df.drop('W_1_3',axis = 'columns')
df = df.drop('W_1_4',axis = 'columns')
df = df.drop('W_1_5',axis = 'columns')
df = df.drop('W_1_6',axis = 'columns')
df = df.drop('W_1_7',axis = 'columns')
df = df.drop('W_1_8',axis = 'columns')
df = df.drop('W_1_9',axis = 'columns')
df = df.drop('W_1_10',axis = 'columns')
df = df.drop('W_1_11',axis = 'columns')
df = df.drop('W_1_51',axis = 'columns')
df = df.drop('W_1_52',axis = 'columns')
df = df.drop('W_1_39',axis = 'columns')
df = df.drop('W_1_40',axis = 'columns')
df = df.drop('W_1_41',axis = 'columns')
df = df.drop('W_1_42',axis = 'columns')
df = df.drop('W_1_43',axis = 'columns')
df = df.drop('W_1_44',axis = 'columns')
df = df.drop('W_1_45',axis = 'columns')
df = df.drop('W_1_46',axis = 'columns')
df = df.drop('W_1_47',axis = 'columns')
df = df.drop('W_1_48',axis = 'columns')
df = df.drop('W_1_49',axis = 'columns')
df = df.drop('W_1_50',axis = 'columns')

# %%
df = df.drop('W_3_1',axis = 'columns')
df = df.drop('W_3_2',axis = 'columns')
df = df.drop('W_3_3',axis = 'columns')
df = df.drop('W_3_4',axis = 'columns')
df = df.drop('W_3_5',axis = 'columns')
df = df.drop('W_3_6',axis = 'columns')
df = df.drop('W_3_7',axis = 'columns')
df = df.drop('W_3_8',axis = 'columns')
df = df.drop('W_3_9',axis = 'columns')
df = df.drop('W_3_10',axis = 'columns')
df = df.drop('W_3_11',axis = 'columns')
df = df.drop('W_3_51',axis = 'columns')
df = df.drop('W_3_52',axis = 'columns')
df = df.drop('W_3_12',axis = 'columns')
df = df.drop('W_3_13',axis = 'columns')
df = df.drop('W_3_14',axis = 'columns')
df = df.drop('W_3_15',axis = 'columns')
df = df.drop('W_3_16',axis = 'columns')
df = df.drop('W_3_17',axis = 'columns')
df = df.drop('W_3_18',axis = 'columns')
df = df.drop('W_3_19',axis = 'columns')
df = df.drop('W_3_20',axis = 'columns')
df = df.drop('W_3_21',axis = 'columns')
df = df.drop('W_3_22',axis = 'columns')
df = df.drop('W_3_23',axis = 'columns')
df = df.drop('W_3_24',axis = 'columns')
df = df.drop('W_3_25',axis = 'columns')
df = df.drop('W_3_26',axis = 'columns')
df = df.drop('W_3_27',axis = 'columns')
df = df.drop('W_3_28',axis = 'columns')
df = df.drop('W_3_29',axis = 'columns')
df = df.drop('W_3_30',axis = 'columns')
df = df.drop('W_3_31',axis = 'columns')
df = df.drop('W_3_32',axis = 'columns')
df = df.drop('W_3_33',axis = 'columns')
df = df.drop('W_3_34',axis = 'columns')
df = df.drop('W_3_35',axis = 'columns')
df = df.drop('W_3_36',axis = 'columns')
df = df.drop('W_3_37',axis = 'columns')
df = df.drop('W_3_38',axis = 'columns')
df = df.drop('W_3_39',axis = 'columns')
df = df.drop('W_3_40',axis = 'columns')
df = df.drop('W_3_41',axis = 'columns')
df = df.drop('W_3_42',axis = 'columns')
df = df.drop('W_3_43',axis = 'columns')
df = df.drop('W_3_44',axis = 'columns')
df = df.drop('W_3_45',axis = 'columns')
df = df.drop('W_3_46',axis = 'columns')
df = df.drop('W_3_47',axis = 'columns')
df = df.drop('W_3_48',axis = 'columns')
df = df.drop('W_3_49',axis = 'columns')
df = df.drop('W_3_50',axis = 'columns')

# %%
df['Plantation_1'] = df.apply(lambda x: sum(list([x['P_3'],
                                        x['P_4'],
                                        x['P_5'],
                                        x['P_6'],
                                        ])),axis = 1)

# %%
df['Plantation_2'] = df.apply(lambda x: sum(list([x['P_7'],
                                        x['P_8'],
                                        x['P_9'],
                                        x['P_10'],
                                        ])),axis = 1)

# %%
df = df.drop('P_3', axis = 'columns')
df = df.drop('P_4', axis = 'columns')
df = df.drop('P_5', axis = 'columns')
df = df.drop('P_6', axis = 'columns')
df = df.drop('P_7', axis = 'columns')
df = df.drop('P_8', axis = 'columns')
df = df.drop('P_9', axis = 'columns')
df = df.drop('P_10', axis = 'columns')

# %%
from statistics import mean

# %%
df['Winter_2'] = df.apply(lambda x: mean(list([x['W_2_1'],
                                        x['W_2_2'],
                                        x['W_2_3'],
                                        x['W_2_4'],
                                        x['W_2_5'],
                                        x['W_2_6'],
                                        x['W_2_7'],
                                        x['W_2_8'], 
                                        x['W_2_9'],
                                        x['W_2_10'],
                                        x['W_2_11'],
                                        x['W_2_51'],
                                        x['W_2_52'],
                                        ])),axis=1)

# %%
df = df.drop('W_2_1',axis = 'columns')
df = df.drop('W_2_2',axis = 'columns')
df = df.drop('W_2_3',axis = 'columns')
df = df.drop('W_2_4',axis = 'columns')
df = df.drop('W_2_5',axis = 'columns')
df = df.drop('W_2_6',axis = 'columns')
df = df.drop('W_2_7',axis = 'columns')
df = df.drop('W_2_8',axis = 'columns')
df = df.drop('W_2_9',axis = 'columns')
df = df.drop('W_2_10',axis = 'columns')
df = df.drop('W_2_11',axis = 'columns')
df = df.drop('W_2_51',axis = 'columns')
df = df.drop('W_2_52',axis = 'columns')

# %%
df['Winter_4'] = df.apply(lambda x: mean(list([x['W_4_1'],
                                        x['W_4_2'],
                                        x['W_4_3'],
                                        x['W_4_4'],
                                        x['W_4_5'],
                                        x['W_4_6'],
                                        x['W_4_7'],
                                        x['W_4_8'], 
                                        x['W_4_9'],
                                        x['W_4_10'],
                                        x['W_4_11'],
                                        x['W_4_51'],
                                        x['W_4_52'],
                                        ])),axis=1)

# %%
df = df.drop('W_4_1',axis = 'columns')
df = df.drop('W_4_2',axis = 'columns')
df = df.drop('W_4_3',axis = 'columns')
df = df.drop('W_4_4',axis = 'columns')
df = df.drop('W_4_5',axis = 'columns')
df = df.drop('W_4_6',axis = 'columns')
df = df.drop('W_4_7',axis = 'columns')
df = df.drop('W_4_8',axis = 'columns')
df = df.drop('W_4_9',axis = 'columns')
df = df.drop('W_4_10',axis = 'columns')
df = df.drop('W_4_11',axis = 'columns')
df = df.drop('W_4_51',axis = 'columns')
df = df.drop('W_4_52',axis = 'columns')

# %%
df['Winter_5'] = df.apply(lambda x: mean(list([x['W_5_1'],
                                        x['W_5_2'],
                                        x['W_5_3'],
                                        x['W_5_4'],
                                        x['W_5_5'],
                                        x['W_5_6'],
                                        x['W_5_7'],
                                        x['W_5_8'], 
                                        x['W_5_9'],
                                        x['W_5_10'],
                                        x['W_5_11'],
                                        x['W_5_51'],
                                        x['W_5_52'],
                                        ])),axis=1)

# %%
df = df.drop('W_5_1',axis = 'columns')
df = df.drop('W_5_2',axis = 'columns')
df = df.drop('W_5_3',axis = 'columns')
df = df.drop('W_5_4',axis = 'columns')
df = df.drop('W_5_5',axis = 'columns')
df = df.drop('W_5_6',axis = 'columns')
df = df.drop('W_5_7',axis = 'columns')
df = df.drop('W_5_8',axis = 'columns')
df = df.drop('W_5_9',axis = 'columns')
df = df.drop('W_5_10',axis = 'columns')
df = df.drop('W_5_11',axis = 'columns')
df = df.drop('W_5_51',axis = 'columns')
df = df.drop('W_5_52',axis = 'columns')

# %%
df['Winter_6'] = df.apply(lambda x: mean(list([x['W_6_1'],
                                        x['W_6_2'],
                                        x['W_6_3'],
                                        x['W_6_4'],
                                        x['W_6_5'],
                                        x['W_6_6'],
                                        x['W_6_7'],
                                        x['W_6_8'], 
                                        x['W_6_9'],
                                        x['W_6_10'],
                                        x['W_6_11'],
                                        x['W_6_51'],
                                        x['W_6_52'],
                                        ])),axis=1)

# %%
df = df.drop('W_6_1',axis = 'columns')
df = df.drop('W_6_2',axis = 'columns')
df = df.drop('W_6_3',axis = 'columns')
df = df.drop('W_6_4',axis = 'columns')
df = df.drop('W_6_5',axis = 'columns')
df = df.drop('W_6_6',axis = 'columns')
df = df.drop('W_6_7',axis = 'columns')
df = df.drop('W_6_8',axis = 'columns')
df = df.drop('W_6_9',axis = 'columns')
df = df.drop('W_6_10',axis = 'columns')
df = df.drop('W_6_11',axis = 'columns')
df = df.drop('W_6_51',axis = 'columns')
df = df.drop('W_6_52',axis = 'columns')

# %%
df
# Out:
#        yield    W_1_12    W_1_13     W_1_14     W_1_15    W_1_16    W_1_17  \
# 0       32.5  3.175824  6.472527   1.736264   5.505495  0.648352  0.000000
# 1       36.0  0.197802  1.593407   0.670330  11.934066  5.417582  2.241758
# 2       37.0  3.296703  1.483516   5.857143   0.923077  5.692308  0.329670
# 3       23.0  1.879121  7.076923  11.219780   3.571429  0.879121  2.406593
# 4       28.5  5.351648  3.252747   2.868132   4.945055  3.098901  2.956044
# ...      ...       ...       ...        ...        ...       ...       ...
# 25340   51.9  0.666667  0.000000   0.452381   2.452381  1.785714  0.190476
# 25341   57.6  1.523810  5.011905   0.880952   0.000000  8.761905  6.988095
# 25342   52.9  2.095238  0.523810   4.035714   2.071429  3.130952  1.119048
# 25343   20.5  5.257937  1.984127   1.333333   0.087302  0.980159  3.682540
# 25344   24.4  0.000000  0.726190   0.400794   0.472222  3.365079  4.111111
#
#          W_1_18    W_1_19     W_1_20  ...  soc_mean_15-30cm  soc_mean_30-60cm  \
# 0      0.000000  1.153846   8.769231  ...        104.991802         72.170593
# 1      1.450549  7.120879  14.703297  ...        104.991802         72.170593
# 2      0.945055  0.439560   5.329670  ...        104.991802         72.170593
# 3      9.406593  2.098901   2.560440  ...        104.991802         72.170593
# 4      6.010989  0.142857   3.527473  ...        104.991802         72.170593
# ...         ...       ...        ...  ...               ...               ...
# 25340  1.047619  3.428571   6.273810  ...        144.437596         85.114330
# 25341  4.880952  5.738095   0.000000  ...        144.437596         85.114330
# 25342  9.642857  0.511905   8.642857  ...        144.437596         85.114330
# 25343  0.111111  3.234127   0.027778  ...        109.129032         70.720430
# 25344  2.638889  0.119048   2.138889  ...        109.129032         70.720430
#
#        soc_mean_60-100cm  soc_mean_100-200cm  Plantation_1  Plantation_2  \
# 0              36.379682           20.656740          73.0          26.0
# 1              36.379682           20.656740          21.0          67.0
# 2              36.379682           20.656740          80.0          18.0
# 3              36.379682           20.656740          45.0          54.0
# 4              36.379682           20.656740          40.0          56.0
# ...                  ...                 ...           ...           ...
# 25340          46.119877           26.919877          60.0          39.0
# 25341          46.119877           26.919877          74.0          23.0
# 25342          46.119877           26.919877          70.0          28.0
# 25343          40.344086           28.408602          47.0          49.0
# 25344          40.344086           28.408602          84.0          13.0
#
#          Winter_2  Winter_4   Winter_5    Winter_6
# 0      268.238039  1.548077  -7.665416  362.502113
# 1      280.365512  4.652790  -6.860260  384.564666
# 2      266.704312  2.112954  -8.220573  392.104818
# 3      262.741167  3.329406  -5.398616  471.369400
# 4      248.714455  4.780959  -5.311285  451.458157
# ...           ...       ...        ...         ...
# 25340  279.880220  2.263221 -10.699176  281.094322
# 25341  273.535165  3.112637  -7.830357  365.228938
# 25342  254.889378  2.138107  -8.494391  287.449634
# 25343  245.533700 -0.806090 -11.754502  260.848596
# 25344  251.025397  4.352659  -9.608097  224.920635
#
# [25345 rows x 256 columns]

# %%
df['Spring_1'] = df.apply(lambda x: mean(list([x['W_1_12'],
                                        x['W_1_13'],
                                        x['W_1_14'],
                                        x['W_1_15'],
                                        x['W_1_16'],
                                        x['W_1_17'],
                                        x['W_1_18'], 
                                        x['W_1_19'],
                                        x['W_1_20'],
                                        x['W_1_21'],
                                        x['W_1_22'],
                                        x['W_1_23'],
                                        x['W_1_24'],     
                                        ])),axis=1)

# %%
df = df.drop('W_1_12',axis = 'columns')
df = df.drop('W_1_13',axis = 'columns')
df = df.drop('W_1_14',axis = 'columns')
df = df.drop('W_1_15',axis = 'columns')
df = df.drop('W_1_16',axis = 'columns')
df = df.drop('W_1_17',axis = 'columns')
df = df.drop('W_1_18',axis = 'columns')
df = df.drop('W_1_19',axis = 'columns')
df = df.drop('W_1_20',axis = 'columns')
df = df.drop('W_1_21',axis = 'columns')
df = df.drop('W_1_22',axis = 'columns')
df = df.drop('W_1_23',axis = 'columns')
df = df.drop('W_1_24',axis = 'columns')

# %%
df['Spring_2'] = df.apply(lambda x: mean(list([x['W_2_12'],
                                        x['W_2_13'],
                                        x['W_2_14'],
                                        x['W_2_15'],
                                        x['W_2_16'],
                                        x['W_2_17'],
                                        x['W_2_18'], 
                                        x['W_2_19'],
                                        x['W_2_20'],
                                        x['W_2_21'],
                                        x['W_2_22'],
                                        x['W_2_23'],
                                        x['W_2_24'],     
                                        ])),axis=1)

# %%
df = df.drop('W_2_12',axis = 'columns')
df = df.drop('W_2_13',axis = 'columns')
df = df.drop('W_2_14',axis = 'columns')
df = df.drop('W_2_15',axis = 'columns')
df = df.drop('W_2_16',axis = 'columns')
df = df.drop('W_2_17',axis = 'columns')
df = df.drop('W_2_18',axis = 'columns')
df = df.drop('W_2_19',axis = 'columns')
df = df.drop('W_2_20',axis = 'columns')
df = df.drop('W_2_21',axis = 'columns')
df = df.drop('W_2_22',axis = 'columns')
df = df.drop('W_2_23',axis = 'columns')
df = df.drop('W_2_24',axis = 'columns')

# %%
df['Spring_4'] = df.apply(lambda x: mean(list([x['W_4_12'],
                                        x['W_4_13'],
                                        x['W_4_14'],
                                        x['W_4_15'],
                                        x['W_4_16'],
                                        x['W_4_17'],
                                        x['W_4_18'], 
                                        x['W_4_19'],
                                        x['W_4_20'],
                                        x['W_4_21'],
                                        x['W_4_22'],
                                        x['W_4_23'],
                                        x['W_4_24'],     
                                        ])),axis=1)

# %%
df = df.drop('W_4_12',axis = 'columns')
df = df.drop('W_4_13',axis = 'columns')
df = df.drop('W_4_14',axis = 'columns')
df = df.drop('W_4_15',axis = 'columns')
df = df.drop('W_4_16',axis = 'columns')
df = df.drop('W_4_17',axis = 'columns')
df = df.drop('W_4_18',axis = 'columns')
df = df.drop('W_4_19',axis = 'columns')
df = df.drop('W_4_20',axis = 'columns')
df = df.drop('W_4_21',axis = 'columns')
df = df.drop('W_4_22',axis = 'columns')
df = df.drop('W_4_23',axis = 'columns')
df = df.drop('W_4_24',axis = 'columns')

# %%
df['Spring_5'] = df.apply(lambda x: mean(list([x['W_5_12'],
                                        x['W_5_13'],
                                        x['W_5_14'],
                                        x['W_5_15'],
                                        x['W_5_16'],
                                        x['W_5_17'],
                                        x['W_5_18'], 
                                        x['W_5_19'],
                                        x['W_5_20'],
                                        x['W_5_21'],
                                        x['W_5_22'],
                                        x['W_5_23'],
                                        x['W_5_24'],     
                                        ])),axis=1)

# %%
df = df.drop('W_5_12',axis = 'columns')
df = df.drop('W_5_13',axis = 'columns')
df = df.drop('W_5_14',axis = 'columns')
df = df.drop('W_5_15',axis = 'columns')
df = df.drop('W_5_16',axis = 'columns')
df = df.drop('W_5_17',axis = 'columns')
df = df.drop('W_5_18',axis = 'columns')
df = df.drop('W_5_19',axis = 'columns')
df = df.drop('W_5_20',axis = 'columns')
df = df.drop('W_5_21',axis = 'columns')
df = df.drop('W_5_22',axis = 'columns')
df = df.drop('W_5_23',axis = 'columns')
df = df.drop('W_5_24',axis = 'columns')

# %%
df['Spring_6'] = df.apply(lambda x: mean(list([x['W_6_12'],
                                        x['W_6_13'],
                                        x['W_6_14'],
                                        x['W_6_15'],
                                        x['W_6_16'],
                                        x['W_6_17'],
                                        x['W_6_18'], 
                                        x['W_6_19'],
                                        x['W_6_20'],
                                        x['W_6_21'],
                                        x['W_6_22'],
                                        x['W_6_23'],
                                        x['W_6_24'],     
                                        ])),axis=1)

# %%
df = df.drop('W_6_12',axis = 'columns')
df = df.drop('W_6_13',axis = 'columns')
df = df.drop('W_6_14',axis = 'columns')
df = df.drop('W_6_15',axis = 'columns')
df = df.drop('W_6_16',axis = 'columns')
df = df.drop('W_6_17',axis = 'columns')
df = df.drop('W_6_18',axis = 'columns')
df = df.drop('W_6_19',axis = 'columns')
df = df.drop('W_6_20',axis = 'columns')
df = df.drop('W_6_21',axis = 'columns')
df = df.drop('W_6_22',axis = 'columns')
df = df.drop('W_6_23',axis = 'columns')
df = df.drop('W_6_24',axis = 'columns')

# %%
df
# Out:
#        yield    W_1_25    W_1_26     W_1_27    W_1_28    W_1_29     W_1_30  \
# 0       32.5  0.472527  0.791209   6.989011  0.021978  2.241758   2.538462
# 1       36.0  9.439560  5.571429  15.417582  4.758242  8.340659  19.296703
# 2       37.0  3.065934  3.956044  12.560440  3.131868  8.835165   0.791209
# 3       23.0  0.780220  0.637363   1.494505  0.000000  0.000000   0.131868
# 4       28.5  0.329670  1.560440   3.296703  2.912088  8.285714   5.351648
# ...      ...       ...       ...        ...       ...       ...        ...
# 25340   51.9  0.488095  2.261905   7.666667  0.000000  2.119048   8.833333
# 25341   57.6  4.166667  0.666667   1.869048  0.511905  3.428571   0.869048
# 25342   52.9  1.011905  5.142857   0.059524  0.047619  1.119048   2.892857
# 25343   20.5  0.543651  3.365079   4.535714  5.825397  0.496032   0.813492
# 25344   24.4  0.932540  1.571429   2.182540  0.444444  1.091270   2.333333
#
#          W_1_31    W_1_32     W_1_33  ...  Plantation_2    Winter_2  Winter_4  \
# 0      0.362637  6.175824  10.252747  ...          26.0  268.238039  1.548077
# 1      0.571429  2.087912   2.395604  ...          67.0  280.365512  4.652790
# 2      0.000000  5.483516   2.032967  ...          18.0  266.704312  2.112954
# 3      2.912088  0.263736   0.000000  ...          54.0  262.741167  3.329406
# 4      0.000000  0.000000   2.054945  ...          56.0  248.714455  4.780959
# ...         ...       ...        ...  ...           ...         ...       ...
# 25340  0.071429  5.023810   5.988095  ...          39.0  279.880220  2.263221
# 25341  1.892857  1.857143   5.904762  ...          23.0  273.535165  3.112637
# 25342  1.654762  2.000000   6.880952  ...          28.0  254.889378  2.138107
# 25343  0.087302  6.742063   2.948413  ...          49.0  245.533700 -0.806090
# 25344  0.440476  0.380952   1.107143  ...          13.0  251.025397  4.352659
#
#         Winter_5    Winter_6  Spring_1    Spring_2   Spring_4  Spring_5  \
# 0      -7.665416  362.502113  3.310228  397.113779  20.740068  8.656382
# 1      -6.860260  384.564666  4.704987  379.880304  21.931953  9.902367
# 2      -8.220573  392.104818  3.792899  384.105495  19.776839  8.169062
# 3      -5.398616  471.369400  3.828402  386.093660  17.210904  6.988166
# 4      -5.311285  451.458157  4.526627  383.269654  18.449704  8.210482
# ...          ...         ...       ...         ...        ...       ...
# 25340 -10.699176  281.094322  2.222527  381.972161  20.443223  6.241300
# 25341  -7.830357  365.228938  3.643773  382.801466  19.612179  6.468407
# 25342  -8.494391  287.449634  2.804029  389.884250  20.003663  7.159341
# 25343 -11.754502  260.848596  1.866606  402.938217  15.442766  2.498626
# 25344  -9.608097  224.920635  1.913309  403.451038  21.368437  5.299145
#
#           Spring_6
# 0      1163.854607
# 1      1219.983094
# 2      1186.272189
# 3      1082.062553
# 4      1180.253593
# ...            ...
# 25340   727.179487
# 25341  1040.073260
# 25342  1019.047619
# 25343   683.711844
# 25344   595.262515
#
# [25345 rows x 196 columns]

# %%
df['Summer_1'] = df.apply(lambda x: mean(list([x['W_1_25'],
                                        x['W_1_26'],
                                        x['W_1_27'],
                                        x['W_1_28'],
                                        x['W_1_29'],
                                        x['W_1_30'],
                                        x['W_1_31'], 
                                        x['W_1_32'],
                                        x['W_1_33'],
                                        x['W_1_34'],
                                        x['W_1_35'],
                                        x['W_1_36'],
                                        x['W_1_37'], 
                                        x['W_1_38']
                                        ])),axis=1)

# %%
df = df.drop('W_1_25',axis = 'columns')
df = df.drop('W_1_26',axis = 'columns')
df = df.drop('W_1_27',axis = 'columns')
df = df.drop('W_1_28',axis = 'columns')
df = df.drop('W_1_29',axis = 'columns')
df = df.drop('W_1_30',axis = 'columns')
df = df.drop('W_1_31',axis = 'columns')
df = df.drop('W_1_32',axis = 'columns')
df = df.drop('W_1_33',axis = 'columns')
df = df.drop('W_1_34',axis = 'columns')
df = df.drop('W_1_35',axis = 'columns')
df = df.drop('W_1_36',axis = 'columns')
df = df.drop('W_1_37',axis = 'columns')
df = df.drop('W_1_38',axis = 'columns')

# %%
df['Summer_2'] = df.apply(lambda x: mean(list([x['W_2_25'],
                                        x['W_2_26'],
                                        x['W_2_27'],
                                        x['W_2_28'],
                                        x['W_2_29'],
                                        x['W_2_30'],
                                        x['W_2_31'], 
                                        x['W_2_32'],
                                        x['W_2_33'],
                                        x['W_2_34'],
                                        x['W_2_35'],
                                        x['W_2_36'],
                                        x['W_2_37'], 
                                        x['W_2_38']
                                        ])),axis=1)

# %%
df = df.drop('W_2_25',axis = 'columns')
df = df.drop('W_2_26',axis = 'columns')
df = df.drop('W_2_27',axis = 'columns')
df = df.drop('W_2_28',axis = 'columns')
df = df.drop('W_2_29',axis = 'columns')
df = df.drop('W_2_30',axis = 'columns')
df = df.drop('W_2_31',axis = 'columns')
df = df.drop('W_2_32',axis = 'columns')
df = df.drop('W_2_33',axis = 'columns')
df = df.drop('W_2_34',axis = 'columns')
df = df.drop('W_2_35',axis = 'columns')
df = df.drop('W_2_36',axis = 'columns')
df = df.drop('W_2_37',axis = 'columns')
df = df.drop('W_2_38',axis = 'columns')

# %%
df['Summer_4'] = df.apply(lambda x: mean(list([x['W_4_25'],
                                        x['W_4_26'],
                                        x['W_4_27'],
                                        x['W_4_28'],
                                        x['W_4_29'],
                                        x['W_4_30'],
                                        x['W_4_31'], 
                                        x['W_4_32'],
                                        x['W_4_33'],
                                        x['W_4_34'],
                                        x['W_4_35'],
                                        x['W_4_36'],
                                        x['W_4_37'], 
                                        x['W_4_38']
                                        ])),axis=1)

# %%
df = df.drop('W_4_25',axis = 'columns')
df = df.drop('W_4_26',axis = 'columns')
df = df.drop('W_4_27',axis = 'columns')
df = df.drop('W_4_28',axis = 'columns')
df = df.drop('W_4_29',axis = 'columns')
df = df.drop('W_4_30',axis = 'columns')
df = df.drop('W_4_31',axis = 'columns')
df = df.drop('W_4_32',axis = 'columns')
df = df.drop('W_4_33',axis = 'columns')
df = df.drop('W_4_34',axis = 'columns')
df = df.drop('W_4_35',axis = 'columns')
df = df.drop('W_4_36',axis = 'columns')
df = df.drop('W_4_37',axis = 'columns')
df = df.drop('W_4_38',axis = 'columns')

# %%
df['Summer_5'] = df.apply(lambda x: mean(list([x['W_5_25'],
                                        x['W_5_26'],
                                        x['W_5_27'],
                                        x['W_5_28'],
                                        x['W_5_29'],
                                        x['W_5_30'],
                                        x['W_5_31'], 
                                        x['W_5_32'],
                                        x['W_5_33'],
                                        x['W_5_34'],
                                        x['W_5_35'],
                                        x['W_5_36'],
                                        x['W_5_37'], 
                                        x['W_5_38']
                                        ])),axis=1)

# %%
df = df.drop('W_5_25',axis = 'columns')
df = df.drop('W_5_26',axis = 'columns')
df = df.drop('W_5_27',axis = 'columns')
df = df.drop('W_5_28',axis = 'columns')
df = df.drop('W_5_29',axis = 'columns')
df = df.drop('W_5_30',axis = 'columns')
df = df.drop('W_5_31',axis = 'columns')
df = df.drop('W_5_32',axis = 'columns')
df = df.drop('W_5_33',axis = 'columns')
df = df.drop('W_5_34',axis = 'columns')
df = df.drop('W_5_35',axis = 'columns')
df = df.drop('W_5_36',axis = 'columns')
df = df.drop('W_5_37',axis = 'columns')
df = df.drop('W_5_38',axis = 'columns')

# %%
df['Summer_6'] = df.apply(lambda x: mean(list([x['W_6_25'],
                                        x['W_6_26'],
                                        x['W_6_27'],
                                        x['W_6_28'],
                                        x['W_6_29'],
                                        x['W_6_30'],
                                        x['W_6_31'], 
                                        x['W_6_32'],
                                        x['W_6_33'],
                                        x['W_6_34'],
                                        x['W_6_35'],
                                        x['W_6_36'],
                                        x['W_6_37'], 
                                        x['W_6_38']
                                        ])),axis=1)

# %%
df = df.drop('W_6_25',axis = 'columns')
df = df.drop('W_6_26',axis = 'columns')
df = df.drop('W_6_27',axis = 'columns')
df = df.drop('W_6_28',axis = 'columns')
df = df.drop('W_6_29',axis = 'columns')
df = df.drop('W_6_30',axis = 'columns')
df = df.drop('W_6_31',axis = 'columns')
df = df.drop('W_6_32',axis = 'columns')
df = df.drop('W_6_33',axis = 'columns')
df = df.drop('W_6_34',axis = 'columns')
df = df.drop('W_6_35',axis = 'columns')
df = df.drop('W_6_36',axis = 'columns')
df = df.drop('W_6_37',axis = 'columns')
df = df.drop('W_6_38',axis = 'columns')

# %%
df['Fall_2'] = df.apply(lambda x: mean(list([x['W_2_39'],
                                        x['W_2_40'],
                                        x['W_2_41'],
                                        x['W_2_42'],
                                        x['W_2_43'],
                                        x['W_2_44'],
                                        x['W_2_45'], 
                                        x['W_2_46'],
                                        x['W_2_47'],
                                        x['W_2_48'],
                                        x['W_2_49'],
                                        x['W_2_50']
                                        ])),axis=1)

# %%
df = df.drop('W_2_39',axis = 'columns')
df = df.drop('W_2_40',axis = 'columns')
df = df.drop('W_2_41',axis = 'columns')
df = df.drop('W_2_42',axis = 'columns')
df = df.drop('W_2_43',axis = 'columns')
df = df.drop('W_2_44',axis = 'columns')
df = df.drop('W_2_45',axis = 'columns')
df = df.drop('W_2_46',axis = 'columns')
df = df.drop('W_2_47',axis = 'columns')
df = df.drop('W_2_48',axis = 'columns')
df = df.drop('W_2_49',axis = 'columns')
df = df.drop('W_2_50',axis = 'columns')

# %%
df['Fall_4'] = df.apply(lambda x: mean(list([x['W_4_39'],
                                        x['W_4_40'],
                                        x['W_4_41'],
                                        x['W_4_42'],
                                        x['W_4_43'],
                                        x['W_4_44'],
                                        x['W_4_45'], 
                                        x['W_4_46'],
                                        x['W_4_47'],
                                        x['W_4_48'],
                                        x['W_4_49'],
                                        x['W_4_50']
                                        ])),axis=1)

# %%
df = df.drop('W_4_39',axis = 'columns')
df = df.drop('W_4_40',axis = 'columns')
df = df.drop('W_4_41',axis = 'columns')
df = df.drop('W_4_42',axis = 'columns')
df = df.drop('W_4_43',axis = 'columns')
df = df.drop('W_4_44',axis = 'columns')
df = df.drop('W_4_45',axis = 'columns')
df = df.drop('W_4_46',axis = 'columns')
df = df.drop('W_4_47',axis = 'columns')
df = df.drop('W_4_48',axis = 'columns')
df = df.drop('W_4_49',axis = 'columns')
df = df.drop('W_4_50',axis = 'columns')

# %%
df['Fall_5'] = df.apply(lambda x: mean(list([x['W_5_39'],
                                        x['W_5_40'],
                                        x['W_5_41'],
                                        x['W_5_42'],
                                        x['W_5_43'],
                                        x['W_5_44'],
                                        x['W_5_45'], 
                                        x['W_5_46'],
                                        x['W_5_47'],
                                        x['W_5_48'],
                                        x['W_5_49'],
                                        x['W_5_50']
                                        ])),axis=1)

# %%
df = df.drop('W_5_39',axis = 'columns')
df = df.drop('W_5_40',axis = 'columns')
df = df.drop('W_5_41',axis = 'columns')
df = df.drop('W_5_42',axis = 'columns')
df = df.drop('W_5_43',axis = 'columns')
df = df.drop('W_5_44',axis = 'columns')
df = df.drop('W_5_45',axis = 'columns')
df = df.drop('W_5_46',axis = 'columns')
df = df.drop('W_5_47',axis = 'columns')
df = df.drop('W_5_48',axis = 'columns')
df = df.drop('W_5_49',axis = 'columns')
df = df.drop('W_5_50',axis = 'columns')

# %%
df['Fall_6'] = df.apply(lambda x: mean(list([x['W_6_39'],
                                        x['W_6_40'],
                                        x['W_6_41'],
                                        x['W_6_42'],
                                        x['W_6_43'],
                                        x['W_6_44'],
                                        x['W_6_45'], 
                                        x['W_6_46'],
                                        x['W_6_47'],
                                        x['W_6_48'],
                                        x['W_6_49'],
                                        x['W_6_50']
                                        ])),axis=1)

# %%
df = df.drop('W_6_39',axis = 'columns')
df = df.drop('W_6_40',axis = 'columns')
df = df.drop('W_6_41',axis = 'columns')
df = df.drop('W_6_42',axis = 'columns')
df = df.drop('W_6_43',axis = 'columns')
df = df.drop('W_6_44',axis = 'columns')
df = df.drop('W_6_45',axis = 'columns')
df = df.drop('W_6_46',axis = 'columns')
df = df.drop('W_6_47',axis = 'columns')
df = df.drop('W_6_48',axis = 'columns')
df = df.drop('W_6_49',axis = 'columns')
df = df.drop('W_6_50',axis = 'columns')

# %%
df
# Out:
#        yield  bdod_mean_0-5cm  bdod_mean_5-15cm  bdod_mean_15-30cm  \
# 0       32.5       143.206081        153.367438         155.579849
# 1       36.0       143.206081        153.367438         155.579849
# 2       37.0       143.206081        153.367438         155.579849
# 3       23.0       143.206081        153.367438         155.579849
# 4       28.5       143.206081        153.367438         155.579849
# ...      ...              ...               ...                ...
# 25340   51.9       139.970724        151.351002         153.205855
# 25341   57.6       139.970724        151.351002         153.205855
# 25342   52.9       139.970724        151.351002         153.205855
# 25343   20.5       135.086022        151.096774         157.634409
# 25344   24.4       135.086022        151.096774         157.634409
#
#        bdod_mean_30-60cm  bdod_mean_60-100cm  bdod_mean_100-200cm  \
# 0             163.814050          167.271869           168.043063
# 1             163.814050          167.271869           168.043063
# 2             163.814050          167.271869           168.043063
# 3             163.814050          167.271869           168.043063
# 4             163.814050          167.271869           168.043063
# ...                  ...                 ...                  ...
# 25340         154.596302          155.533128           155.631741
# 25341         154.596302          155.533128           155.631741
# 25342         154.596302          155.533128           155.631741
# 25343         163.602151          163.666667           163.376344
# 25344         163.602151          163.666667           163.376344
#
# Summer_6                    0.557247           0.517377            0.460762
# Fall_2                      0.521758           0.310246            0.161511
# Fall_4                      0.574423           0.433791            0.318081
# Fall_5                      0.582026           0.564092            0.528685
# Fall_6                      0.546820           0.557533            0.535788
#
#                    bdod_mean_100-200cm  cec_mean_0-5cm  cec_mean_5-15cm  \
# yield                         0.012427       -0.116560        -0.059508
# bdod_mean_0-5cm               0.306675       -0.379249        -0.224589
# bdod_mean_5-15cm              0.520068       -0.414985        -0.355696
# bdod_mean_15-30cm             0.512980       -0.433779        -0.351036
# bdod_mean_30-60cm             0.784042       -0.213524        -0.235143
# ...                                ...             ...              ...
# Summer_6                      0.345906       -0.376060        -0.362938
# Fall_2                        0.011940       -0.646313        -0.496518
# Fall_4                        0.193823       -0.595444        -0.537289
# Fall_5                        0.457602       -0.452570        -0.495519
# Fall_6                        0.472519       -0.397681        -0.464849
#
#                    cec_mean_15-30cm  ...  Spring_6  Summer_1  Summer_2  \
# yield                     -0.033984  ...  0.118500  0.271071 -0.114275
# bdod_mean_0-5cm           -0.072808  ...  0.387589  0.100469  0.285659
# bdod_mean_5-15cm          -0.226442  ...  0.509792  0.120180  0.251034
# bdod_mean_15-30cm         -0.206592  ...  0.500303  0.072600  0.298329
# bdod_mean_30-60cm         -0.130646  ...  0.526977  0.164685  0.107921
# ...                             ...  ...       ...       ...       ...
# Summer_6                  -0.225521  ...  0.772567  0.211875  0.068966
# Fall_2                    -0.324185  ...  0.416557 -0.025635  0.557412
# Fall_4                    -0.378345  ...  0.633262 -0.022380  0.533826
# Fall_5                    -0.367864  ...  0.788913  0.151232  0.292346
# Fall_6                    -0.349981  ...  0.800328  0.179270  0.212769
#
#                    Summer_4  Summer_5  Summer_6    Fall_2    Fall_4    Fall_5  \
# yield             -0.222932 -0.008828  0.043985 -0.005560  0.034063  0.100419
# bdod_mean_0-5cm    0.322945  0.435460  0.387929  0.439347  0.444903  0.451820
# bdod_mean_5-15cm   0.358897  0.528161  0.503235  0.447888  0.512741  0.565576
# bdod_mean_15-30cm  0.469519  0.589779  0.557247  0.521758  0.574423  0.582026
# bdod_mean_30-60cm  0.302115  0.515018  0.517377  0.310246  0.433791  0.564092
# ...                     ...       ...       ...       ...       ...       ...
# Summer_6           0.607670  0.933292  1.000000  0.577476  0.682458  0.738864
# Fall_2             0.726335  0.675793  0.577476  1.000000  0.776004  0.462453
# Fall_4             0.707260  0.744528  0.682458  0.776004  1.000000  0.844219
# Fall_5             0.491356  0.749604  0.738864  0.462453  0.844219  1.000000
# Fall_6             0.445851  0.743741  0.755459  0.398025  0.771015  0.968804
#
#                      Fall_6
# yield              0.088183
# bdod_mean_0-5cm    0.392932
# bdod_mean_5-15cm   0.523106
# bdod_mean_15-30cm  0.546820
# bdod_mean_30-60cm  0.557533
# ...                     ...
# Summer_6           0.755459
# Fall_2             0.398025
# Fall_4             0.771015
# Fall_5             0.968804
# Fall_6             1.000000
#
# [87 rows x 87 columns]

# %%
y = df['yield']
x = df.drop('yield',axis = 'columns')

# %%
import numpy as np
corr_matrix = x.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
to_drop = [column for column in upper.columns if any(upper[column] > 0.8)]
print(to_drop)
x.drop(to_drop, axis=1, inplace=True)
df.drop(to_drop, axis=1, inplace=True)
# Out:
# ['bdod_mean_15-30cm', 'bdod_mean_30-60cm', 'bdod_mean_60-100cm', 'bdod_mean_100-200cm', 'cec_mean_5-15cm', 'cec_mean_15-30cm', 'cec_mean_30-60cm', 'cec_mean_60-100cm', 'cec_mean_100-200cm', 'cfvo_mean_5-15cm', 'cfvo_mean_15-30cm', 'cfvo_mean_30-60cm', 'cfvo_mean_60-100cm', 'cfvo_mean_100-200cm', 'clay_mean_5-15cm', 'clay_mean_15-30cm', 'clay_mean_30-60cm', 'clay_mean_60-100cm', 'clay_mean_100-200cm', 'nitrogen_mean_15-30cm', 'nitrogen_mean_30-60cm', 'nitrogen_mean_60-100cm', 'nitrogen_mean_100-200cm', 'ocd_mean_5-15cm', 'ocd_mean_15-30cm', 'ocd_mean_30-60cm', 'ocd_mean_60-100cm', 'ocd_mean_100-200cm', 'ocs_mean_0-5cm', 'ocs_mean_5-15cm', 'ocs_mean_15-30cm', 'ocs_mean_30-60cm', 'ocs_mean_60-100cm', 'ocs_mean_100-200cm', 'phh2o_mean_5-15cm', 'phh2o_mean_15-30cm', 'phh2o_mean_30-60cm', 'phh2o_mean_60-100cm', 'phh2o_mean_100-200cm', 'sand_mean_0-5cm', 'sand_mean_5-15cm', 'sand_mean_15-30cm', 'sand_mean_30-60cm', 'sand_mean_60-100cm', 'sand_mean_100-200cm', 'silt_mean_0-5cm', 'silt_mean_5-15cm', 'silt_mean_15-30cm', 'silt_mean_30-60cm', 'silt_mean_60-100cm', 'silt_mean_100-200cm', 'soc_mean_0-5cm', 'soc_mean_5-15cm', 'soc_mean_15-30cm', 'soc_mean_30-60cm', 'soc_mean_60-100cm', 'soc_mean_100-200cm', 'Plantation_2', 'Winter_5', 'Winter_6', 'Spring_5', 'Spring_6', 'Summer_6', 'Fall_5', 'Fall_6']

# %%
import numpy as np
from keras.utils import to_categorical
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=5)

print(x_train.shape)
print(x_test.shape)
# Out:
# 2023-05-18 22:14:09.533174: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (20276, 21)
# (5069, 21)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train)
from joblib import dump, load
dump(scaler, 'std_scaler.bin', compress=True)
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
for col in x.columns:
    print(col)
x.shape
# Out:
# bdod_mean_0-5cm
# bdod_mean_5-15cm
# cec_mean_0-5cm
# cfvo_mean_0-5cm
# clay_mean_0-5cm
# nitrogen_mean_0-5cm
# nitrogen_mean_5-15cm
# ocd_mean_0-5cm
# phh2o_mean_0-5cm
# Plantation_1
# Winter_2
# Winter_4
# Spring_1
# Spring_2
# Spring_4
# Summer_1
# Summer_2
# Summer_4
# Summer_5
# Fall_2
# Fall_4
# (25345, 21)

# %%
x
# Out:
#        bdod_mean_0-5cm  bdod_mean_5-15cm  cec_mean_0-5cm  cfvo_mean_0-5cm  \
# 0           143.206081        153.367438      211.594104         7.935735
# 1           143.206081        153.367438      211.594104         7.935735
# 2           143.206081        153.367438      211.594104         7.935735
# 1       36.0       143.206081        153.367438      211.594104
# 2       37.0       143.206081        153.367438      211.594104
# 3       23.0       143.206081        153.367438      211.594104
# 4       28.5       143.206081        153.367438      211.594104
# ...      ...              ...               ...             ...
# 25340   51.9       139.970724        151.351002      236.169183
# 25341   57.6       139.970724        151.351002      236.169183
# 25342   52.9       139.970724        151.351002      236.169183
# 25343   20.5       135.086022        151.096774      242.591398
# 25344   24.4       135.086022        151.096774      242.591398
#
#        cfvo_mean_0-5cm  clay_mean_0-5cm  nitrogen_mean_0-5cm  \
# 0             7.935735       301.355030          3809.589225
# 1             7.935735       301.355030          3809.589225
# 2             7.935735       301.355030          3809.589225
# 3             7.935735       301.355030          3809.589225
# 4             7.935735       301.355030          3809.589225
# ...                ...              ...                  ...
# 25340         6.073652       325.487827          2973.209861
# 25341         6.073652       325.487827          2973.209861
# 25342         6.073652       325.487827          2973.209861
# 25343         8.698925       300.010753          2615.817204
# 25344         8.698925       300.010753          2615.817204
#
#        nitrogen_mean_5-15cm  ocd_mean_0-5cm  phh2o_mean_0-5cm  ...  Winter_4  \
# 0               1728.220492      383.528392         62.645905  ...  1.548077
# 1               1728.220492      383.528392         62.645905  ...  4.652790
# 2               1728.220492      383.528392         62.645905  ...  2.112954
# 3               1728.220492      383.528392         62.645905  ...  3.329406
# 4               1728.220492      383.528392         62.645905  ...  4.780959
# ...                     ...             ...               ...  ...       ...
# 25340           1871.551310      388.928814         67.213867  ...  2.263221
# 25341           1871.551310      388.928814         67.213867  ...  3.112637
# 25342           1871.551310      388.928814         67.213867  ...  2.138107
# 25343           1575.860215      369.139785         69.440860  ... -0.806090
# 25344           1575.860215      369.139785         69.440860  ...  4.352659
#
#        Spring_1    Spring_2   Spring_4  Summer_1    Summer_2   Summer_4  \
# 0      3.310228  397.113779  20.740068  4.058085  363.297959  31.789246
# 1      4.704987  379.880304  21.931953  5.496075  371.845526  28.076531
# 2      3.792899  384.105495  19.776839  4.077708  370.049608  27.722920
# 3      3.828402  386.093660  17.210904  1.741758  388.543799  32.417975
# 4      4.526627  383.269654  18.449704  2.802983  385.996860  29.673862
# ...         ...         ...        ...       ...         ...        ...
# 25340  2.222527  381.972161  20.443223  3.383503  372.032653  28.144558
# 25341  3.643773  382.801466  19.612179  3.198129  368.157824  28.924320
# 25342  2.804029  389.884250  20.003663  2.370748  372.960544  28.295068
# 25343  1.866606  402.938217  15.442766  2.104592  390.739229  27.637897
# 25344  1.913309  403.451038  21.368437  0.748866  402.310204  31.658730
#
#         Summer_5      Fall_2     Fall_4
# 0      18.839874  247.490110  14.617216
# 1      16.813187  235.091575  14.455586
# 2      16.607928  237.978022  14.357601
# 3      18.779435  225.731868  13.866758
# 4      16.895212  235.654212  14.347070
# ...          ...         ...        ...
# 25340  15.405612  221.942857  13.721230
# 25341  16.109694  227.431746  13.196429
# 25342  14.826531  228.904762  12.827877
# 25343  12.691893  208.225397   8.032242
# 25344  13.921769  221.896296  11.686508
#
# [25345 rows x 22 columns]

# %%
from keras.layers import Input, Dropout, Dense, Convolution1D, Flatten, MaxPooling1D, AveragePooling1D
from keras.models import Sequential

# %%
from keras import backend

def rmse(y_true, y_pred):
    return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))

# %%
cnn_model = Sequential()
cnn_model.add(Convolution1D(filters = 32, kernel_size = 5, input_shape=(x_train.shape[1],1), padding='same', activation='elu'))
cnn_model.add(AveragePooling1D(2))
cnn_model.add(Convolution1D(filters = 16, kernel_size = 5, activation='elu'))
cnn_model.add(AveragePooling1D(2))
cnn_model.add(Dropout(0.2))
cnn_model.add(Flatten())
cnn_model.add(Dense(32, activation='elu'))
cnn_model.add(Dense(16, activation='elu'))
cnn_model.add(Dense(1, activation='linear'))

cnn_model.compile(loss='mse',optimizer='adam', metrics=['mape',rmse])
cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 21, 32)            192
#
#  average_pooling1d (AverageP  (None, 10, 32)           0
#  ooling1D)
#
#  conv1d_1 (Conv1D)           (None, 6, 16)             2576
#
#  average_pooling1d_1 (Averag  (None, 3, 16)            0
#  ePooling1D)
#
#  dropout (Dropout)           (None, 3, 16)             0
#
#  flatten (Flatten)           (None, 48)                0
#
#  dense (Dense)               (None, 32)                1568
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 4,881
# Trainable params: 4,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = cnn_model.fit(x_train_scaled, y_train, validation_data=(x_test_scaled, y_test), batch_size=20, epochs=100)
# Out:
# Epoch 1/100
# 1014/1014 [==============================] - 2s 1ms/step - loss: 170.1909 - mape: 28.9298 - rmse: 9.5337 - val_loss: 66.6770 - val_mape: 20.6954 - val_rmse: 6.5616
# Epoch 2/100
# 1014/1014 [==============================] - 1s 1ms/step - loss: 72.2513 - mape: 20.2479 - rmse: 6.7413 - val_loss: 55.6541 - val_mape: 17.8182 - val_rmse: 5.9500
# Epoch 3/100
# 1014/1014 [==============================] - 1s 1ms/step - loss: 65.5687 - mape: 19.0831 - rmse: 6.3951 - val_loss: 54.1800 - val_mape: 17.0002 - val_rmse: 5.8495
# Epoch 4/100
# 1014/1014 [==============================] - 1s 1ms/step - loss: 61.8512 - mape: 18.5346 - rmse: 6.2174 - val_loss: 52.0100 - val_mape: 17.1548 - val_rmse: 5.7514
# Epoch 5/100
# 1014/1014 [==============================] - 1s 1ms/step - loss: 58.9692 - mape: 18.1110 - rmse: 6.0784 - val_loss: 50.6466 - val_mape: 17.2143 - val_rmse: 5.6973
# Epoch 6/100
# 1014/1014 [==============================] - 1s 1ms/step - loss: 57.3923 - mape: 17.7906 - rmse: 5.9856 - val_loss: 51.3483 - val_mape: 17.8623 - val_rmse: 5.7538
# Epoch 7/100
# 1014/1014 [==============================] - 1s 1ms/step - loss: 55.7523 - mape: 17.5310 - rmse: 5.8890 - val_loss: 49.7236 - val_mape: 17.3714 - val_rmse: 5.6538
# Epoch 8/100
# 1014/1014 [==============================] - 1s 1ms/step - loss: 54.8147 - mape: 17.3697 - rmse: 5.8348 - val_loss: 48.5052 - val_mape: 15.8986 - val_rmse: 5.5127
# Epoch 9/100
# 1014/1014 [==============================] - 1s 1ms/step - loss: 53.4276 - mape: 17.0669 - rmse: 5.7478 - val_loss: 46.3547 - val_mape: 16.1202 - val_rmse: 5.4249
# Epoch 10/100
# 1014/1014 [==============================] - 1s 1ms/step - loss: 52.5347 - mape: 16.9105 - rmse: 5.7009 - val_loss: 46.1044 - val_mape: 16.3994 - val_rmse: 5.4278
# Epoch 11/100
# 1014/1014 [==============================] - 1s 1ms/step - loss: 51.2553 - mape: 16.6956 - rmse: 5.6234 - val_loss: 45.4013 - val_mape: 16.3012 - val_rmse: 5.3767
# Epoch 12/100
# 1014/1014 [==============================] - 1s 1ms/step - loss: 51.1129 - mape: 16.6698 - rmse: 5.6180 - val_loss: 44.8079 - val_mape: 15.8401 - val_rmse: 5.3410
# Epoch 13/100
# 1014/1014 [==============================] - 1s 1ms/step - loss:
100
# 1014/1014 [==============================] - 1s 1ms/step - loss: 31.3656 - mape: 13.0722 - rmse: 4.3689 - val_loss: 26.5376 - val_mape: 11.9971 - val_rmse: 4.0266
# Epoch 98/100
# 1014/1014 [==============================] - 1s 1ms/step - loss: 31.5091 - mape: 13.1005 - rmse: 4.3798 - val_loss: 26.2855 - val_mape: 11.9269 - val_rmse: 4.0108
# Epoch 99/100
# 1014/1014 [==============================] - 1s 1ms/step - loss: 31.4231 - mape: 13.1079 - rmse: 4.3751 - val_loss: 26.9357 - val_mape: 12.4396 - val_rmse: 4.0429
# Epoch 100/100
# 1014/1014 [==============================] - 1s 1ms/step - loss: 31.5240 - mape: 13.0969 - rmse: 4.3768 - val_loss: 27.4218 - val_mape: 12.6635 - val_rmse: 4.1074

# %%
input_shape=(x_train.shape[1],1)
print(input_shape)
# Out:
# (21, 1)

# %%
count = 0
for r in range(0,1):
    actual = df.iloc[r,0]
    r0 = x.iloc[r,0]
    r1 = x.iloc[r,1]
    r2 = x.iloc[r,2]
    r3 = x.iloc[r,3]
    r4 = x.iloc[r,4]
    r5 = x.iloc[r,5]
    r6 = x.iloc[r,6]
    r7 = x.iloc[r,7]
    r8 = x.iloc[r,8]
    r9 = x.iloc[r,9]
    r10 = x.iloc[r,10]
    r11 = x.iloc[r,11]
    r12 = x.iloc[r,12]
    r13 = x.iloc[r,13]
    r14 = x.iloc[r,14]
    r15 = x.iloc[r,15]
    r16 = x.iloc[r,16]
    r17 = x.iloc[r,17]
    r18 = x.iloc[r,18]
    r19 = x.iloc[r,19]
    r20 = x.iloc[r,20]
    pred = pd.DataFrame([[r0,r1,r2,r3,r4,r5,r6,r7,r8,r9,r10,r11,r12,r13,r14,r15,r16,r17,r18,r19,r20]], columns=['bdod_mean_0-5cm', 'bdod_mean_5-15cm', 'cec_mean_0-5cm', 'cfvo_mean_0-5cm', 'clay_mean_0-5cm', 'nitrogen_mean_0-5cm', 'nitrogen_mean_5-15cm', 'ocd_mean_0-5cm', 'phh2o_mean_0-5cm', 'Plantation_1', 'Winter_2', 'Winter_4', 'Spring_1', 'Spring_2', 'Spring_4', 'Summer_1', 'Summer_2', 'Summer_4', 'Summer_5', 'Fall_2', 'Fall_4'])
    pred_scaled = scaler.transform(pred)
    prediction = cnn_model.predict(pred_scaled)
    if (prediction < actual-5 or prediction > actual+5):
        count = count+1
    print(count,end="                     -----------------------------              -----  ")
    print(r)
    print(prediction)
    print(actual)
    

print(count)
# Out:
# 1/1 [==============================] - 0s 143ms/step
# 0                     -----------------------------              -----  0
# [[28.83225]]
# 32.5
# 0

# %%
cnn_model.predict(pd.DataFrame([[r0,r1,r2,r3,r4,r5,r6,r7,r8,r9,r10,r11,r12,r13,r14,r15,r16,r17,r18,r19,r20]], columns=['bdod_mean_0-5cm', 'bdod_mean_5-15cm', 'cec_mean_0-5cm', 'cfvo_mean_0-5cm', 'clay_mean_0-5cm', 'nitrogen_mean_0-5cm', 'nitrogen_mean_5-15cm', 'ocd_mean_0-5cm', 'phh2o_mean_0-5cm', 'Plantation_1', 'Winter_2', 'Winter_4', 'Spring_1', 'Spring_2', 'Spring_4', 'Summer_1', 'Summer_2', 'Summer_4', 'Summer_5', 'Fall_2', 'Fall_4']))
# Out:
# 1/1 [==============================] - 0s 92ms/step
# array([[130.3436]], dtype=float32)

# %%
from matplotlib import pyplot
pyplot.plot(hist.history['rmse'])
pyplot.plot(hist.history['mape'])
pyplot.show()

# %%
from sklearn.metrics import confusion_matrix
from matplotlib import pyplot
import seaborn as sns
sns.set()

bins = np.array([0,5,15,25,35,45,55,65])

y_pred = cnn_model.predict(x_test_scaled)

y_true_bin = np.digitize(y_test, bins)
y_pred_bin = np.digitize(y_pred, bins)

mat = confusion_matrix(y_true_bin, y_pred_bin)
class_labels = ['0-5','5-15','15-25','25-35','35-45','55-65','65-85']

hmap = sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False, cmap='Blues',
               xticklabels=class_labels,
               yticklabels=class_labels)

hmap.set_xlabel('Predicted label')
hmap.set_ylabel('Actual label')

pyplot.show()
# Out:
# 159/159 [==============================] - 0s 813us/step

# %%
import streamlit as st
import numpy as np
import pandas as pd
from streamlit_option_menu import option_menu
from tensorflow import keras
from keras import layers
from keras.models import Sequential
from sklearn.preprocessing import StandardScaler

st.title('CROP MODELLING YIELD PREDICTION')
with st.sidebar:
    selected = option_menu("Model Selection", ['CNN', 'LSTM', 'BiLSTM'])

if selected == 'CNN':
    st.write("CNN_Model is currently selected")
    ##lst = []
    result1 = st.number_input("bdod_mean_0-5cm", format="%f")
    ##lst = lst + [result1]
    result2 = st.number_input("bdod_mean_5-15cm", format="%f")
    ##lst = lst + [result2]
    result3 = st.number_input("cec_mean_0-5cm", format="%f")
    ##lst = lst + [result3]
    result4 = st.number_input("cfvo_mean_0-5cm", format="%f")
    ##lst = lst + [result4]
    result5 = st.number_input("clay_mean_0-5cm", format="%f")
    ##lst = lst + [result5]
    result6 = st.number_input("nitrogen_mean_0-5cm", format="%f")
    ##lst = lst + [result6]
    result7 = st.number_input("nitrogen_mean_5-15cm", format="%f")
    ##lst = lst + [result6]
    result8 = st.number_input("ocd_mean_0-5cm", format="%f")
    ##lst = lst + [result1]
    result9 = st.number_input("phh2o_mean_0-5cm", format="%f")
    ##lst = lst + [result1]
    result10 = st.number_input("Plantation_1", format="%f")
    ##lst = lst + [result1]
    result11 = st.number_input("Winter_2", format="%f")
    ##lst = lst + [result1]
    result12 = st.number_input("Winter_4", format="%f")
    ##lst = lst + [result1]
    result13 = st.number_input("Spring_1", format="%f")
    ##lst = lst + [result1]
    result14 = st.number_input("Spring_2", format="%f")
    ##lst = lst + [result1]
    result15 = st.number_input("Spring_4", format="%f")
    ##lst = lst + [result1]
    result16 = st.number_input("Summer_1", format="%f")
    ##lst = lst + [result1]
    result17 = st.number_input("Summer_2", format="%f")
    ##lst = lst + [result1]
    result18 = st.number_input("Summer_4", format="%f")
    ##lst = lst + [result1]
    result19 = st.number_input("Summer_5", format="%f")
    ##lst = lst + [result1]
    result20 = st.number_input("Fall_2", format="%f")
    ##lst = lst + [result1]
    result21 = st.number_input("Fall_4", format="%f")
    ##lst = lst + [result1]
    
    from keras import backend
    def rmse(y_true, y_pred):
        return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))
    
    from joblib import dump, load
    scaler = load('std_scaler.bin')
    from keras.models import model_from_json
    json_file = open('cnn_model.json', 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    loaded_model = model_from_json(loaded_model_json)
    #loaded_model.compile(loss='mse',optimizer='adam', metrics=['mape',rmse])
    loaded_model.load_weights("cnn_model.h5")
    ##input_array = np.array(lst).reshape(1, -1)
    test_data = pd.DataFrame([[result1, result2, result3, result4, result5, result6, result7, result8, result9, result10, result11, result12, result13, result14, result15, result16, result17, result18, result19, result20, result21]], columns=['bdod_mean_0-5cm', 'bdod_mean_5-15cm', 'cec_mean_0-5cm', 'cfvo_mean_0-5cm', 'clay_mean_0-5cm', 'nitrogen_mean_0-5cm', 'nitrogen_mean_5-15cm', 'ocd_mean_0-5cm', 'phh2o_mean_0-5cm', 'Plantation_1', 'Winter_2', 'Winter_4', 'Spring_1', 'Spring_2', 'Spring_4', 'Summer_1', 'Summer_2', 'Summer_4', 'Summer_5', 'Fall_2', 'Fall_4'])
    
    test_data_scaled = scaler.transform(test_data)
    prediction = loaded_model.predict(test_data_scaled)
    st.write(prediction)
    
elif selected == 'LSTM':
    st.write("LSTM_Model is currently selected")
    lst = []
    result1 = st.number_input("bdod_mean_0-5cm", format="%f")
    lst = lst + [result1]
    result2 = st.number_input("bdod_mean_5-15cm", format="%f")
    lst = lst + [result2]
    result3 = st.number_input("cec_mean_0-5cm", format="%f")
    lst = lst + [result3]
    result4 = st.number_input("cfvo_mean_0-5cm", format="%f")
    lst = lst + [result4]
    result5 = st.number_input("clay_mean_0-5cm", format="%f")
    lst = lst + [result5]
    result6 = st.number_input("nitrogen_mean_0-5cm", format="%f")
    lst = lst + [result6]
    result6 = st.number_input("nitrogen_mean_5-15cm", format="%f")
    lst = lst + [result6]
    result1 = st.number_input("ocd_mean_0-5cm", format="%f")
    lst = lst + [result1]
    result1 = st.number_input("phh2o_mean_0-5cm", format="%f")
    lst = lst + [result1]
    result1 = st.number_input("Plantation_1", format="%f")
    lst = lst + [result1]
    result1 = st.number_input("Winter_2", format="%f")
    lst = lst + [result1]
    result1 = st.number_input("Winter_4", format="%f")
    lst = lst + [result1]
    result1 = st.number_input("Spring_1", format="%f")
    lst = lst + [result1]
    result1 = st.number_input("Spring_2", format="%f")
    lst = lst + [result1]
    result1 = st.number_input("Spring_4", format="%f")
    lst = lst + [result1]
    result1 = st.number_input("Summer_1", format="%f")
    lst = lst + [result1]
    result1 = st.number_input("Summer_2", format="%f")
    lst = lst + [result1]
    result1 = st.number_input("Summer_4", format="%f")
    lst = lst + [result1]
    result1 = st.number_input("Summer_5", format="%f")
    lst = lst + [result1]
    result1 = st.number_input("Fall_2", format="%f")
    lst = lst + [result1]
    result1 = st.number_input("Fall_4", format="%f")
    lst = lst + [result1]
    
    from keras import backend

    def rmse(y_true, y_pred):
        return backend.sqrt(backend.mean(backend.square(y_pred - y_true), axis=-1))
    
    from tensorflow.keras.models import model_from_json
    json_file = open('lstm_model.json', 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    loaded_model = model_from_json(loaded_model_json)
    loaded_model.load_weights("lstm_model.h5")
    input_array = np.array(lst).reshape(1, -1)
    prediction = loaded_model.predict(input_array)
elif selected == 'BiLSTM':
    st.write("BiLSTM model")
    
if __name__ == "__main__":
    st.write([result1, result2, result3, result4, result5, result6, result7, result8, result9, result10, result11, result12, result13, result14, result15, result16, result17, result18, result19, result20, result21])

# %%
cnn_model_json = cnn_model.to_json()
with open("cnn_model.json", "w") as json_file:
    json_file.write(cnn_model_json)
cnn_model.save_weights("cnn_model.h5")

# %%
from keras.layers import Input, Dropout, Dense, LSTM, Flatten
from keras.models import Sequential

# %%
lstm_model = Sequential()
lstm_model.add(LSTM(32, return_sequences = True, input_shape=(x_train.shape[1],1)))
lstm_model.add(Dropout(0.2))
lstm_model.add(Flatten())
lstm_model.add(Dense(10))
lstm_model.add(Dense(1))

lstm_model.compile(loss='mse',optimizer='adam', metrics=['mape',rmse])
lstm_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 21, 32)            4352
#
#  dropout_4 (Dropout)         (None, 21, 32)            0
#
#  flatten_4 (Flatten)         (None, 672)               0
#
#  dense_10 (Dense)            (None, 10)                6730
#
#  dense_11 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 11,093
# Trainable params: 11,093
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = lstm_model.fit(x_train_scaled, y_train, validation_data=(x_test_scaled, y_test), batch_size=20, epochs=30)
# Out:
# Epoch 1/30
# 1014/1014 [==============================] - 7s 6ms/step - loss: 147.9346 - mape: 27.4954 - rmse: 8.8838 - val_loss: 74.2487 - val_mape: 22.8773 - val_rmse: 6.9455
# Epoch 2/30
# 1014/1014 [==============================] - 5s 5ms/step - loss: 74.0528 - mape: 21.0834 - rmse: 6.8439 - val_loss: 64.7883 - val_mape: 20.5654 - val_rmse: 6.4913
# Epoch 3/30
# 1014/1014 [==============================] - 5s 5ms/step - loss: 68.9818 - mape: 20.1138 - rmse: 6.5867 - val_loss: 64.6170 - val_mape: 18.4232 - val_rmse: 6.3908
# Epoch 4/30
# 1014/1014 [==============================] - 6s 6ms/step - loss: 65.2651 - mape: 19.4681 - rmse: 6.4127 - val_loss: 57.9433 - val_mape: 18.2538 - val_rmse: 6.0770
# Epoch 5/30
# 1014/1014 [==============================] - 7s 7ms/step - loss: 62.1513 - mape: 18.7781 - rmse: 6.2526 - val_loss: 54.6726 - val_mape: 17.4146 - val_rmse: 5.9059
# Epoch 6/30
# 1014/1014 [==============================] - 7s 7ms/step - loss: 59.5852 - mape: 18.3199 - rmse: 6.1167 - val_loss: 53.4113 - val_mape: 17.5146 - val_rmse: 5.8627
# Epoch 7/30
# 1014/1014 [==============================] - 6s 6ms/step - loss: 58.2090 - mape: 18.0347 - rmse: 6.0355 - val_loss: 52.0006 - val_mape: 17.8151 - val_rmse: 5.7890
# Epoch 8/30
# 1014/1014 [==============================] - 7s 7ms/step - loss: 56.8271 - mape: 17.7122 - rmse: 5.9513 - val_loss: 49.9828 - val_mape: 17.0725 - val_rmse: 5.6541
# Epoch 9/30
# 1014/1014 [==============================] - 7s 7ms/step - loss: 56.0111 - mape: 17.6112 - rmse: 5.9158 - val_loss: 49.6550 - val_mape: 16.8039 - val_rmse: 5.6170
# Epoch 10/30
# 1014/1014 [==============================] - 7s 7ms/step - loss: 54.6825 - mape: 17.3766 - rmse: 5.8496 - val_loss: 48.4935 - val_mape: 17.1268 - val_rmse: 5.5755
# Epoch 26/30
# 1014/1014 [==============================] - 7s 7ms/step - loss: 40.5489 - mape: 14.7414 - rmse: 5.0094 - val_loss: 36.3743 - val_mape: 14.2674 - val_rmse: 4.7671
# Epoch 27/30
# 1014/1014 [==============================] - 7s 7ms/step - loss: 39.9220 - mape: 14.5931 - rmse: 4.9466 - val_loss: 35.0430 - val_mape: 13.8394 - val_rmse: 4.6754
# Epoch 28/30
# 1014/1014 [==============================] - 7s 7ms/step - loss: 39.2937 - mape: 14.5123 - rmse: 4.9192 - val_loss: 35.1265 - val_mape: 13.6666 - val_rmse: 4.6658
# Epoch 29/30
# 1014/1014 [==============================] - 6s 6ms/step - loss: 38.8989 - mape: 14.3759 - rmse: 4.8834 - val_loss: 34.1998 - val_mape: 13.6618 - val_rmse: 4.6160
# Epoch 30/30
# 1014/1014 [==============================] - 7s 6ms/step - loss: 38.6212 - mape: 14.3693 - rmse: 4.8746 - val_loss: 34.3645 - val_mape: 13.5714 - val_rmse: 4.6211

# %%
from matplotlib import pyplot
pyplot.plot(hist.history['rmse'])
pyplot.plot(hist.history['mape'])
pyplot.show()

# %%
lstm_model_json = lstm_model.to_json()
with open("lstm_model.json", "w") as json_file:
    json_file.write(lstm_model_json)
lstm_model.save_weights("lstm_model.h5")

# %%
from sklearn.metrics import confusion_matrix
from matplotlib import pyplot
import seaborn as sns
sns.set()

bins = np.array([0,5,15,25,35,45,55,65])

y_pred = lstm_model.predict(x_test_scaled)

y_true_bin = np.digitize(y_test, bins)
y_pred_bin = np.digitize(y_pred, bins)

mat = confusion_matrix(y_true_bin, y_pred_bin)
class_labels = ['0-5','5-15','15-25','25-35','35-45','55-65','65-85']

hmap = sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False, cmap='Blues',
               xticklabels=class_labels,
               yticklabels=class_labels)

hmap.set_xlabel('Predicted label')
hmap.set_ylabel('Actual label')

pyplot.show()
# Out:
# 159/159 [==============================] - 1s 2ms/step

# %%
x_train.shape
# Out:
# (20276, 88)

# %%
from keras.layers import Input, Dropout, Dense, LSTM, Flatten, Bidirectional
from keras.models import Sequential

# %%
model = Sequential()
model.add(Bidirectional(LSTM(32, return_sequences = True, input_shape=(1,x_train.shape[1],1))))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(32))
model.add(Dense(1))

model.compile(loss='mse',optimizer='adam', metrics=['mape',rmse])
model.build(input_shape=(1,x_train.shape[1],1))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional_1 (Bidirectio  (1, 21, 64)              8704
#  nal)
#
#  dropout_1 (Dropout)         (1, 21, 64)               0
#
#  flatten_1 (Flatten)         (1, 1344)                 0
#
#  dense_2 (Dense)             (1, 32)                   43040
#
#  dense_3 (Dense)             (1, 1)                    33
#
# =================================================================
# Total params: 51,777
# Trainable params: 51,777
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train_scaled, y_train, validation_data=(x_test_scaled, y_test), batch_size=1, epochs=50)
# Out:
# Epoch 1/50
# 20276/20276 [==============================] - 106s 5ms/step - loss: 74.1886 - mape: 20.2358 - rmse: 6.7328 - val_loss: 54.5666 - val_mape: 16.8521 - val_rmse: 5.8473
# Epoch 2/50
# 20276/20276 [==============================] - 106s 5ms/step - loss: 56.9197 - mape: 17.6251 - rmse: 5.9734 - val_loss: 48.1700 - val_mape: 15.8233 - val_rmse: 5.5301
# 20276/20276 [==============================] - 109s 5ms/step - loss: 16.5363 - mape: 9.3150 - rmse: 3.1603 - val_loss: 21.1518 - val_mape: 10.4261 - val_rmse: 3.5383
# Epoch 49/50
# 20276/20276 [==============================] - 113s 6ms/step - loss: 16.6859 - mape: 9.3493 - rmse: 3.1683 - val_loss: 23.8444 - val_mape: 11.4632 - val_rmse: 3.7406
# Epoch 50/50
# 20276/20276 [==============================] - 150s 7ms/step - loss: 16.5255 - mape: 9.3454 - rmse: 3.1718 - val_loss: 20.6883 - val_mape: 10.4432 - val_rmse: 3.4766

# %%
from matplotlib import pyplot
pyplot.plot(hist.history['rmse'])
pyplot.plot(hist.history['mape'])
pyplot.show()

# %%
bidirectional_model_json = model.to_json()
with open("bidirectional_model.json", "w") as json_file:
    json_file.write(bidirectional_model_json)
model.save_weights("bidirectional_model.h5")

# %%
print(x_test_scaled.shape)
# Out:
# (5069, 21)

# %%
x_test
# Out:
#        bdod_mean_0-5cm  bdod_mean_5-15cm  cec_mean_0-5cm  cfvo_mean_0-5cm  \
# 1446        142.078697        150.542062      192.647232         7.250847
# 4558        142.390276        158.325450      206.525216        15.517291
# 7933        143.901793        153.476228      247.526890         9.776306
# 7091        139.661222        152.086648      238.677557         4.985755
# 12438       139.217343        151.346852      258.088281        21.398835
# ...                ...               ...             ...              ...
# 406         143.525209        148.942897      213.420210         5.095588
# 24324       138.502018        151.173123      255.272068         3.856913
# 24810       138.340248        152.893808      309.799443        11.181987
# 23141       125.953741        137.970328      261.656716        33.007647
# 16044       132.944817        151.091502      278.602293        16.470370
#
#        clay_mean_0-5cm  nitrogen_mean_0-5cm  nitrogen_mean_5-15cm  \
# 1446        218.151864          3005.083164           1238.637288
# 4558        299.497839          5395.482589           2432.332012
# 7933        361.060016          3670.390491           2071.033515
# 7091        361.257102          3642.537642           1977.335227
# 12438       368.946449          3745.333856           2682.682052
# ...                ...                  ...                   ...
# 406         282.824762          3067.368223           1624.886005
# 24324       346.121725          3073.668279           1953.054817
# 24810       438.713401          2917.637264           1959.910864
# 23141       233.266077          4376.144002           2462.302101
# 16044       272.534744          5024.358025           2619.186596
#
#        ocd_mean_0-5cm  phh2o_mean_0-5cm  Plantation_1  ...  Winter_4  \
# 1446       403.715706         58.868249          87.0  ...  9.179640
# 4558       394.449808         63.902378          85.0  ...  0.699863
# 7933       405.839439         61.678878          98.0  ...  2.920730
# 7091       411.030540         60.669744          82.0  ...  5.755037
# 12438      409.041004         63.899395          10.0  ...  6.061355
# ...               ...               ...           ...  ...       ...
# 406        403.088941         60.011831          39.0  ...  3.731015
# 24324      403.524385         65.344619          74.0  ...  3.335263
# 24810      388.860724         70.675023          42.0  ...  0.948639
# 23141      532.615441         70.863000          49.0  ... -5.496606
# 16044      468.313051         63.275485          92.0  ... -1.677266
#
#        Spring_1    Spring_2   Spring_4  Summer_1    Summer_2   Summer_4  \
# 1446   2.660562  396.530403  20.978022  2.410431  395.123810  29.026077
# 4558   3.195971  435.328938  18.582418  2.433673  392.000001  26.762755
# 7091   387.301587  18.807082  2.232426  380.241270  29.369048  17.185941
# 12438  394.013187  19.269689  1.459184  391.725170  33.667942  19.326956
# ...           ...        ...       ...         ...        ...        ...
# 406    388.832653  19.740973  4.889213  378.078134  28.093659  16.404519
# 24324  382.734066  19.128728  2.110787  373.886880  29.007289  15.610058
# 24810  395.625275  17.010817  1.867028  381.545918  28.948182  14.281409
# 23141  378.295023  14.816419  3.096038  354.118607  25.963986  12.837635
# 16044  378.545935  18.808791  4.018367  369.175510  27.063776  15.060204
#
#                19         20
# 1446   247.758731  14.533069
# 4558   225.219048  14.020833
# 7933   243.136508  13.178075
# 7091   244.372487  11.720238
# 12438  239.901588  15.730655
# ...           ...        ...
# 406    253.531973  14.224490
# 24324  225.066666  12.951531
# 24810  219.342857  11.240513
# 23141  195.509243   8.995798
# 16044  200.000000  12.160119
#
# [5069 rows x 21 columns]

# %%
import tensorflow as tf
from sklearn.metrics import confusion_matrix
from matplotlib import pyplot
import seaborn as sns
sns.set()

bins = np.array([0,5,15,25,35,45,55,65])

# x_test_scaled = np.reshape(x_test_scaled,(1,21,1))
# list_tensor = tf.unstack(x_test_scaled)

# stack the list into a tensor with shape [1,1]
# tensor_list = tf.stack(list_tensor)
# xx = x_test.drop(x_test.index[0])
x_test_1 = tf.keras.preprocessing.sequence.pad_sequences(xx, maxlen=x.shape[1], dtype='int32', value=0)
x_test_scaled_1 = scaler.transform(x_test_1)

y_pred = model.predict(x_test_scaled_1)

y_true_bin = np.digitize(y_test, bins)
y_pred_bin = np.digitize(y_pred, bins)

mat = confusion_matrix(y_true_bin, y_pred_bin)
class_labels = ['0-5','5-15','15-25','25-35','35-45','55-65','65-85']

hmap = sns.heatmap(mat, square=True, annot=True, fmt='d', cbar=False, cmap='Blues',
               xticklabels=class_labels,
               yticklabels=class_labels)

hmap.set_xlabel('Predicted label')
hmap.set_ylabel('Actual label')

pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/keras/utils/data_utils.py:1043, in pad_sequences(sequences, maxlen, dtype, padding, truncating, value)
#    1042 try:
# -> 1043     lengths.append(len(x))
#    1044     if flag and len(x):
#
# TypeError: object of type 'int' has no len()
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In [97], line 15
#       7 bins = np.array([0,5,15,25,35,45,55,65])
#       9 # x_test_scaled = np.reshape(x_test_scaled,(1,21,1))
#      10 # list_tensor = tf.unstack(x_test_scaled)
#      11
#      12 # stack the list into a tensor with shape [1,1]
#      13 # tensor_list = tf.stack(list_tensor)
#      14 # xx = x_test.drop(x_test.index[0])
# ---> 15 x_test_1 = tf.keras.preprocessing.sequence.pad_sequences(xx, maxlen=x.shape[1], dtype='int32', value=0)
#      16 x_test_scaled_1 = scaler.transform(x_test_1)
#      18 y_pred = model.predict(x_test_scaled_1)
#
# File ~/.local/lib/python3.8/site-packages/keras/utils/data_utils.py:1048, in pad_sequences(sequences, maxlen, dtype, padding, truncating, value)
#    1046             flag = False
#    1047     except TypeError as e:
# -> 1048         raise ValueError(
#    1049             "`sequences` must be a list of iterables. "
#    1050             f"Found non-iterable: {str(x)}"
#    1051         ) from e
#    1053 if maxlen is None:
#    1054     maxlen = np.max(lengths)
#
# ValueError: `sequences` must be a list of iterables. Found non-iterable: 0
